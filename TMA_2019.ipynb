# %%
import pandas as pd
ACC_2015 = pd.read_csv(r"D:\AOU\TM351\TMA 2019\Accidents_2015.csv")
ACC_2015
# Out:
# C:\Users\salem\AppData\Local\Temp\ipykernel_22820\3164066229.py:2: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   ACC_2015 = pd.read_csv(r"D:\AOU\TM351\TMA 2019\Accidents_2015.csv")
#        Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  \
# 0       201501BS70001               525130.0                180050.0
# 1       201501BS70002               526530.0                178560.0
# 2       201501BS70004               524610.0                181080.0
# 3       201501BS70005               524420.0                181080.0
# 4       201501BS70008               524630.0                179040.0
# ...               ...                    ...                     ...
# 140051  2015984139115               312087.0                570791.0
# 140052  2015984139715               320671.0                569791.0
# 140053  2015984140215               311731.0                586343.0
# ...

# %%
CAS_2015 = pd.read_csv(r"D:\AOU\TM351\TMA 2019\Casualties_2015.csv")
CAS_2015
# Out:
#        Accident_Index  Vehicle_Reference  Casualty_Reference  Casualty_Class  \
# 0       201597UA71710                  2                   1               1
# 1       201597UA71810                  2                   1               2
# 2       201597UA71810                  2                   2               2
# 3       201597UA71810                  2                   3               2
# 4       201597UA71810                  2                   4               2
# ...               ...                ...                 ...             ...
# 186184  201597UA71412                  2                   2               2
# 186185  201597UA71412                  2                   3               1
# 186186  201597UA71510                  1                   1               3
# 186187  201597UA71610                  2                   1               1
# 186188  201597UA71611                  1                   1               1
#
# ...

# %%
ACC_2018 = pd.read_csv(r"D:\AOU\TM351\TMA 2019\dftRoadSafetyData_Accidents_2018.csv")
ACC_2018
# Out:
# C:\Users\salem\AppData\Local\Temp\ipykernel_22820\605752536.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   ACC_2018 = pd.read_csv(r"D:\AOU\TM351\TMA 2019\dftRoadSafetyData_Accidents_2018.csv")
#        Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  \
# 0       2018010080971               529150.0                182270.0
# 1       2018010080973               542020.0                184290.0
# 2       2018010080974               531720.0                182910.0
# 3       2018010080981               541450.0                183220.0
# 4       2018010080982               543580.0                176500.0
# ...               ...                    ...                     ...
# 122630  2018984115718               307124.0                594145.0
# 122631  2018984115918               313325.0                581065.0
# 122632  2018984116018               319337.0                574511.0
# ...

# %%
CAS_2018 = pd.read_csv(r"D:\AOU\TM351\TMA 2019\dftRoadSafetyData_Casualties_2018.csv")
CAS_2018
# Out:
#        Accident_Index  Vehicle_Reference  Casualty_Reference  Casualty_Class  \
# 0       2018010080971                  1                   1               2
# 1       2018010080971                  2                   2               1
# 2       2018010080973                  1                   1               3
# 3       2018010080974                  1                   1               1
# 4       2018010080981                  1                   1               1
# ...               ...                ...                 ...             ...
# 160592  2018984115718                  2                   1               2
# 160593  2018984115918                  1                   1               3
# 160594  2018984116018                  2                   1               2
# 160595  2018984116318                  1                   1               1
# 160596  2018984116418                  1                   1               1
#
# ...

# %%
#Data preparation

# %%
merge_15 = ACC_2015.merge(CAS_2015)
merge_15
# Out:
#        Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  \
# 0       201501BS70001               525130.0                180050.0
# 1       201501BS70002               526530.0                178560.0
# 2       201501BS70004               524610.0                181080.0
# 3       201501BS70005               524420.0                181080.0
# 4       201501BS70008               524630.0                179040.0
# ...               ...                    ...                     ...
# 164515  2015984141415               314050.0                579638.0
# 164516  2015984141415               314050.0                579638.0
# 164517  2015984141415               314050.0                579638.0
# 164518  2015984141415               314050.0                579638.0
# 164519  2015984141415               314050.0                579638.0
#
#         Longitude   Latitude  Police_Force  Accident_Severity  \
# 0       -0.198465  51.505538             1                  3
# ...

# %%
merge_18 = ACC_2018.merge(CAS_2018)
merge_18
# Out:
#        Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  \
# 0       2018010130027               523810.0                185730.0
# 1       2018010130028               517980.0                185050.0
# 2       2018010130028               517980.0                185050.0
# 3       2018010130030               542820.0                182610.0
# 4       2018010130030               542820.0                182610.0
# ...               ...                    ...                     ...
# 140953  2018984115718               307124.0                594145.0
# 140954  2018984115918               313325.0                581065.0
# 140955  2018984116018               319337.0                574511.0
# 140956  2018984116318               318858.0                566932.0
# 140957  2018984116418               316008.0                568771.0
#
#         Longitude   Latitude  Police_Force  Accident_Severity  \
# 0       -0.215455  51.556878             1                  3
# ...

# %%
merge_15.shape
# Out:
# (164520, 47)

# %%
merge_15.isnull().sum()
# Out:
# Accident_Index                                     0
# Location_Easting_OSGR                             37
# Location_Northing_OSGR                            37
# Longitude                                         37
# Latitude                                          37
# Police_Force                                       0
# Accident_Severity                                  0
# Number_of_Vehicles                                 0
# Number_of_Casualties                               0
# Date                                               0
# Day_of_Week                                        0
# Time                                              22
# Local_Authority_(District)                         0
# Local_Authority_(Highway)                          0
# 1st_Road_Class                                     0
# 1st_Road_Number                                    0
# Road_Type                                          0
# Speed_limit                                        0
# ...

# %%
merge_18.shape
# Out:
# (140958, 47)

# %%
merge_18.isnull().sum()
# Out:
# Accident_Index                                    0
# Location_Easting_OSGR                            69
# Location_Northing_OSGR                           69
# Longitude                                        69
# Latitude                                         69
# Police_Force                                      0
# Accident_Severity                                 0
# Number_of_Vehicles                                0
# Number_of_Casualties                              0
# Date                                              0
# Day_of_Week                                       0
# Time                                             20
# Local_Authority_(District)                        0
# Local_Authority_(Highway)                         0
# 1st_Road_Class                                    0
# 1st_Road_Number                                   0
# Road_Type                                         0
# Speed_limit                                       0
# ...

# %%
merge_18['Accident_Severity'].value_counts()
# Out:
# 3    109048
# 2     29198
# 1      2712
# Name: Accident_Severity, dtype: int64

# %%
merge_18['Age_Band_of_Casualty'].value_counts()
# Out:
#  6     27960
#  7     20694
#  8     19777
#  5     15814
#  4     14684
#  9     12767
#  10     7863
#  3      6320
#  11     6268
#  2      4039
#  1      2618
# -1      2154
# Name: Age_Band_of_Casualty, dtype: int64

# %%
clean_18= merge_18.drop(merge_18.query('Age_Band_of_Casualty==-1').index)

# %%
clean_18['Age_Band_of_Casualty'].value_counts()
# Out:
# 6     27960
# 7     20694
# 8     19777
# 5     15814
# 4     14684
# 9     12767
# 10     7863
# 3      6320
# 11     6268
# 2      4039
# 1      2618
# Name: Age_Band_of_Casualty, dtype: int64

# %%
pd.crosstab(clean_18['Accident_Severity'],clean_18['Casualty_Severity'])
# Out:
# Casualty_Severity     1      2       3
# Accident_Severity
# 1                  1713    486     499
# 2                     0  22337    6617
# 3                     0      0  107152

# %%
#Visualizing data
#results

# %%
import matplotlib.pyplot as plt
x=clean_18['Casualty_Severity']
y=clean_18['Accident_Severity']
plt.scatter(x,y)

# %%
import scipy.stats
scipy.stats.spearmanr(clean_18['Accident_Severity'],clean_18['Casualty_Severity'])
# Out:
# SpearmanrResult(correlation=0.8532300138073472, pvalue=0.0)

# %%
corr = clean_18['Accident_Severity'].corr(clean_18['Casualty_Severity'],method="pearson")
corr
# Out:
# 0.8516674912475033
